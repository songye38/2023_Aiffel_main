# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tweepy
import pandas as pd
import konlpy
import gensim

# %% [markdown]
# # 1) 데이터 준비와 확인

# %%
train_data = pd.read_table("./sentimental_classification/data/ratings_train.txt")
test_data = pd.read_table("./sentimental_classification/data/ratings_test.txt")
train_data.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %% [markdown]
# # 2) 데이터로더 구성

# %%
from konlpy.tag import Mecab
import numpy as np
from collections import Counter
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']


def load_data(train_data,test_data,num_words=10000):
    #1. 데이터 중복 제거 
    train_data.drop_duplicates(['document'],inplace=True)
    test_data.drop_duplicates(['document'],inplace=True)
    
    #2. Nan 결측치 제거
    train_data = train_data.dropna(how='any') #각 행마다 하나의 결측치라도 있는 행 삭제하기 
    test_data = test_data.dropna(how='any') #각 행마다 하나의 결측치라도 있는 행 삭제하기 
    
    tokenizer = Mecab()
    X_train = []
    for sentence in tqdm(train_data['document']):
        temp_X = tokenizer.morphs(sentence)    
        temp_X = [word for word in temp_X if not word in stopwords]
        X_train.append(temp_X)
        
    X_test = []
    for sentence in tqdm(test_data['document']):
        temp_X = tokenizer.morphs(sentence)    
        temp_X = [word for word in temp_X if not word in stopwords]
        X_train.append(temp_X)
        
    words = np.concatenate(X_train).tolist()
    counter = Counter(words)
    counter = counter.most_common(10000-4)
    vocab = ['', '', '', ''] + [key for key, _ in counter]
    word_to_index = {word:index for index, word in enumerate(vocab)}
    
    def wordlist_to_indexlist(wordlist):
        return [word_to_index[word] if word in word_to_index else word_to_index[''] for word in wordlist]

    X_train = list(map(wordlist_to_indexlist, X_train))
    X_test = list(map(wordlist_to_indexlist, X_test))
    
    return X_train,np.array(list(train_data['label'])),X_test, np.array(list(test_data['label']))

# %%
from tqdm import tqdm
X_train,y_train,X_test,y_test = load_data(train_data,test_data,num_words=10000)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 146182/146182 [00:12<00:00, 11612.58it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 49157/49157 [00:03<00:00, 12881.28it/s]

# %% [markdown]
# ### 2-1) 데이터의 중복 제거

# %%
train_data.drop_duplicates(['document'],inplace=True)
test_data.drop_duplicates(['document'],inplace=True)
# Out:
# (150000, 3)
# (150000, 3)
# (146183, 3)

# %% [markdown]
# ### 2-2) NaN 결측치 제거

# %%
test_data.isnull().sum() #결측치를 확인해본 결과 리뷰 document에 5개의 결측치가 존재했다. 
test_data = test_data.dropna(how='any') #각 행마다 하나의 결측치라도 있는 행 삭제하기 
train_data = train_data.dropna(how='any') #각 행마다 하나의 결측치라도 있는 행 삭제하기 
test_data.shape #shape 확인해주기
# Out:
# (49157, 3)

# %%
test_data.isnull().sum()
# Out:
# id          0
# document    0
# label       0
# dtype: int64

# %%
train_x = train_data['document'].to_numpy()
train_y = train_data['label'].to_numpy()
test_x = train_data['document'].to_numpy()
test_y = train_data['label'].to_numpy()

# %%
train_x[0]
# Out:
# '아 더빙.. 진짜 짜증나네요 목소리'

# %% [markdown]
# ### 2-3) 한국어 토크나이저로 토큰화

# %%
from konlpy.tag import Okt
from konlpy.tag import Kkma
from tqdm import tqdm

okt = Okt()
kkma = Kkma()

for i in tqdm(range(len(train_x))):
    train_x[i] = okt.morphs(train_x[i])    
print(train_x)
# Out:
# 아 더빙.. 진짜 짜증나네요 목소리
# 100%|██████████████████████████████████| 146182/146182 [14:49<00:00, 164.32it/s]
# [list(['아', '더빙', '..', '진짜', '짜증나네요', '목소리'])
#  list(['흠', '...', '포스터', '보고', '초딩', '영화', '줄', '....', '오버', '연기', '조차', '가볍지', '않구나'])
#  list(['너', '무재', '밓었', '다그', '래서', '보는것을', '추천', '한', '다']) ...
#  list(['이', '게', '뭐', '요', '?', '한국인', '은', '거들', '먹거리', '고', '필리핀', '혼혈', '은', '착하다', '?'])
#  list(['청춘', '영화', '의', '최고봉', '.', '방황', '과', '우울했던', '날', '들', '의', '자화상'])
#  list(['한국', '영화', '최초', '로', '수간', '하는', '내용', '이', '담긴', '영화'])]

# %% [markdown]
# ### 2-4) 불용어(Stopwords) 제거

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']


for i in tqdm(range(len(train_x))):
    train_x[i] = [word for word in train_x[i] if not word in stopwords]
# Out:
# 100%|███████████████████████████████| 146182/146182 [00:00<00:00, 147149.70it/s]

# %%
print(train_x)
# Out:
# [list(['아', '더빙', '..', '진짜', '짜증나네요', '목소리'])
#  list(['흠', '...', '포스터', '보고', '초딩', '영화', '줄', '....', '오버', '연기', '조차', '가볍지', '않구나'])
#  list(['너', '무재', '밓었', '다그', '래서', '보는것을', '추천', '다']) ...
#  list(['게', '뭐', '요', '?', '한국인', '거들', '먹거리', '고', '필리핀', '혼혈', '착하다', '?'])
#  list(['청춘', '영화', '최고봉', '.', '방황', '우울했던', '날', '자화상'])
#  list(['한국', '영화', '최초', '로', '수간', '하는', '내용', '담긴', '영화'])]

# %% [markdown]
# ### 2-5) 사전word_to_index 구성

# %%
train_x_set = set()
for i in tqdm(range(len(train_x))):
    train_x_set.update(train_x[i])
# Out:
# 100%|███████████████████████████████| 146182/146182 [00:00<00:00, 401102.01it/s]
# {'스카이폴', '뜰하다', '받칩니다', '볼수만', '산만했던', '유쾌함은', '브뤼주', '27', '약물중독', '많은듯', '하고있네', '찡기', '6~8', 'ニング', '죽이다니', '같으니라', '싱그러웠어요', '오붓한', '조마조마하면서', '했습니까', '찰톤', '조립', '::::', '가져왔으니', '123345677', '괭장히', '사상충', '디저트', '만드시다니', '스즈랑', '섞인', '넘어갔네', '신우', '14:17', '있다니', '마나', '~~~.', '가리네', '멈추진마', '표상', '있는구먼', '사하는데', '쫒을', '대였던것', '셤기간떄', '페그', '번창', '인서트', '호점떄', '지루하다지만', '영향력', '끄는것이', '뻔했지', '재밌었다고하네요', '내리듯이', '버레스크등', 'UP', '송주호', '했었', '...;;;;;;', '처참하게', '힘들었을까', '불가능하다', '음란하거나', '사시미', '열광한던', '건질게', '레오나르도', '행진', '팔짝', '≥∀≤', '추앙', '아니던', '4천', '윙키', '가줄', '되는것이', '깔끔하다', '살아난거', '많음', '마당', '와항', '그만해라', '중요하고', '보다가관둠', '맞다이는', 'Scene', '자라나는', '휘', '바르게', '갈아타는', '오피러스', '용해주어야', '파고들었으요', '욱껴', '평범한거', '넘었는데도', '남기는지', '악플달지', '므슨', '알았다', '휘청', '이래여', '다뎜벼', '왠만해서', '말았다', '카메론', '모셔놓고', '비웃는다', '토기', '세우는것도', '잊고싶은', '7-8년', '평범하나', '뿔', '돋보였었다', '성장할', '현영은', '메이커', '한수', '명확해졌다', '이길말고', '아련히', '재미있었다고', '끼워줘', '은은하게', '알싸하다', '혼주', '애썼어', '벼', '이쁘구요', '감싼다', '떠돌던', '채웠는데', '알아준다', '비토', '살아온', '주정하', '빼앗아가는', '부통령', '기묘하다', '하진못', '아쉽니다', '보지말고', '날까', '르쉬프', '재밌다지', '사병', 'material', '떠나며', '릅', '랍스타', '죽이', '금순', '귀여운거도', '재밋엇습니', '드려도', '죽는다가', '온더로드', '끔찍함으로', '부스', '쭈쭈', '대단하다하지만', '맘에안드', '왜못', '느꼈죠', '각지', '싱크', '조용하고도', '도잠', '짓하기에', '웃기단', '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~', '어비스', '시사', '싸운다는', '나올수있는', '괜찮던디', '애애애', '가늠', '찾아가고', '불후', '내리쬐는', '드워프', '갔어야', '집안일', '하길', '망인', '뺏지도', '++++', '없어진것', '파는걸', '민망했습니다', '리얄', '쨰', '다르다는데', '자괴', '지나가게', '압축시켜놓은', '말씀드리고싶네요', '김만', '떨어지더라', '방글라데시', '보았지만', '갖지', '꼽힐만', '중요하다던', '따지며', '밋게봣', '혈통', '지하철도', '시킬려고', '구단주', '보때', '못잡음', '안자서', '생생했다', '관대하다니', '보겠는데', '오만한', 'cinecube', '만족하면서', '이르러서', '않나지만', '레볼루션', '원고료', '다니시나', 'don', '나타내는게', '부족하단', '먹을거면', '였다니', '먹느냐', '박상호', '케나', '많은', '원통', '뚤리', '술잔', '잘생기기만', '맄퀴', '그러긴', '스파게티', '잘알지도', '어리져서', '해야겠다', '재미있어요', '살렸음', '음청', '억양', '지으셨어요', '조희봉', '그립더라', '달콤함과', '나오는거야', '그만하길', '적습니다', '위주', '끌려', '독거미', '좋압습니', '알송', '노출한', 'comment', '잊어버리자', '숨쉬네', '이뻣고', '행복할듯', '불간', '스벤', '뜬게', '화려하다', '없었네요', '재섯슴', '화만', 'Tourbillion', '하비', 'for', '부럽냐', '적합한것', '교관', '바뀔거다', '자품', '열면', '클로버', '다녀온건데', '자행', '영빈', 'together', '재수없네', '反', '잠자기는', '연사', '쉴드치는데', '예시', '지하철', '현명해져', '식상하네', '꼴라쥬', '질색', 'vhs', '메롱이', '넣은', '피워', '솔직하네', '봐줄라', '토템', '모르겠거든요', '무섭던가요', '이뻤으면', '멋있지도', '일건데', '잼있다고', '벗어났다', '고를것이다', '과격하게', '내주지', '메로엣타', '완화', '번듯하게', '왕궁', '더듬고', '놀라운데', '웃겨주는', '뿌시', '아줌마', '되나요', '싶어지죠', '났어요', '서브', '박형식', '해주지', '읽나', '한페이', '뎃', '해가는게', '즐겁네요', '김정화', ':))', '잡아가지고', '얕', '바꾸었나', '공익', '엘리스', '방황', '고치는거', '장현성', '버려놓다니', '아쿠아리움', '판을치네요', '썸머', 'GREAT', '부드럽게', 'ㅑ', '용임', '최광호', '관련', '블룩', '빠뜨린듯', '군소리', '바운티', 'http://www.4shared.com/file/nF7zWsvJ/___Split_Second_1992_.html', '97년', '호옹이', '죽이고싶다', '탁트인', '유년기', '닿았었다', '벌', '한프로', '싶으니', '평범하면서도', '좋아하세요', '데드캠프', '신기하기는', '가고싶을지도', '뭐껌', '소권괴초', '2~7', '멈출수없어', '국물', '접하', '멈춰', '반했지', '진공', '바꿔줘서', '위고', '빌리러', '비젼', 'just', '나가요', '청소기', '넘어가더만', '샬토', '바빌론', '십덕', '변하가는게', '뛰어드는', '흑조', '을차지하네요', '해친', '거북함', '자은', '울렸을', '되돌아보게끔', '들인지', '도래', '이선태', 'king', '돌격', '화채', '기괴해서', 'bravo', '더하냐', '됨다고', '개구리', '영화포스터', '뜨면서', '드러난다', '쫀득하', '대단하구요', '들리', '올렸습니다', '나오기까지', 'on', '찐은', '먼이야', '나쁘리란', '줬더군', '하겠는데', '꺼구나', '순경', '가누고', '번정', '나누기', '걸치는', '생이면힘들겠지만', '허경환', '외과의사', '짠하네', '데이터', '다문화', 'tell', '이상하네요', '벗겨놨네', '베릴', '잼있었어', '나소', '보여주고있지', '인조반정', '의한', '먹었다는', '야하며', '하고다니는지', '받았다면', '뺏다', '하하', '긴말안하겠습니다', '드려고', 'FOEVER', '꼽으', '한겨울', '먹으면서', '사준', '보러가겠지만', '귀엽다고다', '뜨는', '이준호', '멋질거', '십대', '아마데우스', '빙그르르', '쟁장', '둘러쌓이면', '박히네요', 'Queen', '싫어합니다', '야생동물', '으릴', '옆구리', '냈지', '귀순', '살피', '보질말던가', '미치겠음', 'ㅇㄻㄴ', '끼다니', '아닌가싶습니다', '신명', '막연히', '되가지고', '떼오라고', '잼내욘', '고를줄', '미칠테고', '뜯으로', '보내질', '아오하라이드', '적인것', '좋아했어요', '때론', '팽귄들', '소리칠', '내는거죠', '부적절한듯', '나왔네', '보고이', '조', '월리스', '미셸', '아버님', '우울하고', '살아있', '진정한것이', '메카', '잘난줄', '해볼게', '살찌웠음', '맞춰주길', '더했던거', '차석구', '미안', '받았지만', '루카', '캠페인', ...

# %%
word_to_index = {}
# 처음 몇 개 인덱스는 사전에 정의되어 있습니다.
word_to_index["<PAD>"] = 0
word_to_index["<BOS>"] = 1
word_to_index["<UNK>"] = 2  # unknown
word_to_index["<UNUSED>"] = 3

# %%
#모든원소들의 집합을 만들기 set으로 만들어주기  -> train_x_set
train_x_list = list(train_x_set)
for i in tqdm(range(len(train_x_list))):
    word_to_index[train_x_list[i]] = i+4
    
print(word_to_index['약물중독'])
# Out:
# 100%|███████████████████████████████| 104659/104659 [00:00<00:00, 883594.80it/s]
# 12

# %% [markdown]
# ### 2-6) 텍스트 스트링을 사전 인덱스 스트링으로 변환

# %%
#['아', '더빙', '..', '진짜', '짜증나네요', '목소리'] -> 숫자들로 변환해주기 
raw_inputs = []
for i in range(len(train_x)):
    raw_inputs.append([word_to_index['<BOS>']]+[word_to_index[word] if word in word_to_index else word_to_index['<UNK>'] for word in train_x[i]])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(raw_inputs[0])
# Out:
# [1, 28750, 101157, 84228, 25273, 49240, 35887]

# %% [markdown]
# ### 2-7) X_train, y_train, X_test, y_test, word_to_index 리턴

# %%
print(train_x[0])
print(train_y[0])
# Out:
# ['아', '더빙', '..', '진짜', '짜증나네요', '목소리']
# 0

# %% [markdown]
# # 3) 모델 구성을 위한 데이터 분석 및 가공

# %% [markdown]
# ### 3-1) 데이터셋 내 문장 길이 분포

# %%
#X_train,y_train,X_test,y_test = load_data(train_data,test_data,num_words=10000)
total_data_size = X_train + X_test
print(len(total_data_size))
# Out:
# 195339

# %% [markdown]
# ### 3-2) 적절한 최대 문장 길이 지정

# %% [markdown]
# ### 3-3) keras.preprocessing.sequence.pad_sequences 을 활용한 패딩 추가

# %% [markdown]
# # 4) 모델 구성 및 validation set 구성 3가지 이상 구상해보기

# %%
#rnn-> LSTM 사용
#cnn 모델

# %% [markdown]
# # 5) 모델 훈련 개시

# %% [markdown]
# # 6) Loss, Accuracy 그래프 시각화

# %% [markdown]
# # 7) 학습된 Embedding 레이어 분석

# %% [markdown]
# # 8) 한국어 Word2Vec 임베딩 활용하여 성능 개선
